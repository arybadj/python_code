# %%
i=1
n=7
while(i<n):
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
i=1
n=7
while(i<n):
    
    
    
    i+=1
    if i==3:
        continue
    print(i)
    
else:
    print("this is the end")
# Out:
# 2
# 4
# 5
# 6
# 7
# this is the end

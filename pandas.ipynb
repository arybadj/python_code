# %%
import pandas as pd

# %%
df=pd.read_csv("laptopPrice.csv")
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
#print top 5 elemts 
df.head() # 5 elemets by default
df.head(10) # 10 elements
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 7    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 8  Lenovo           Intel        Core i5            10th   4 GB     DDR4
# 9    acer             AMD        Ryzen 5            10th   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# ...

# %%
df.tail()
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd   hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 818  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 819  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 820  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 821  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 822   512 GB  0 GB      DOS  64-bit            0 GB  ThinNlight  No warranty
#
# ...

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
df.dtypes #gives datatype
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# weight               object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
df.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     823.000000         823.000000         823.000000
# mean    76745.177400         315.301337          37.609964
# std     45101.790525        1047.382654         121.728017
# min     16990.000000           0.000000           0.000000
# 25%     46095.000000           0.000000           0.000000
# 50%     64990.000000          17.000000           2.000000
# 75%     89636.000000         139.500000          18.000000
# max    441990.000000       15279.000000        1947.000000

# %%
df.shape
# Out:
# (823, 19)

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df['brand']
# Out:
# 0        ASUS
# 1      Lenovo
# 2      Lenovo
# 3        ASUS
# 4        ASUS
#         ...
# 818      ASUS
# 819      ASUS
# 820      ASUS
# 821      ASUS
# 822    Lenovo
# Name: brand, Length: 823, dtype: object

# %%
df['brand'].value_counts()  #count number of brands repeated in table
# Out:
# brand
# ASUS      249
# DELL      151
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      28
# Avita      14
# Name: count, dtype: int64

# %%
df[df['Price']<=20000]
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 12    Avita           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 188    ASUS           Intel   Celeron Dual   Not Available   4 GB   LPDDR4
# 189    ASUS           Intel   Celeron Dual   Not Available   4 GB   LPDDR4
# 194  Lenovo           Intel   Celeron Dual   Not Available   4 GB   LPDDR4
#
#       ssd     hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 12   0 GB  512 GB  Windows  64-bit            0 GB  Casual  No warranty
# 188  0 GB  512 GB  Windows  64-bit            0 GB  Casual  No warranty
# 189  0 GB  512 GB  Windows  32-bit            0 GB  Casual  No warranty
# 194  0 GB  512 GB  Windows  32-bit            0 GB  Casual  No warranty
#
#     Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# 12           No       No  17490  3 stars               1120                196
# ...

# %%
asus_brand=df[df['brand']=='ASUS']
# po=df[df['Price']<=20000,[asus_brand]]
asus_brand_u50k=asus_brand[asus_brand['Price']<=50000]
asus_brand_u50k
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 13   ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 641  ASUS             AMD        Ryzen 3   Not Available   4 GB     DDR4
# 643  ASUS             AMD        Ryzen 3   Not Available   4 GB     DDR4
# 644  ASUS             AMD        Ryzen 3   Not Available   4 GB     DDR4
# 694  ASUS             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 716  ASUS             AMD        Ryzen 5   Not Available   4 GB     DDR4
#
#         ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
asus_storage=df[df['ram_gb']<'5 GB']
asus_storage_brand=asus_storage[asus_storage['brand']=='APPLE']
asus_storage_brand
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 407  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 408  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 601  APPLE              M1             M1            10th  16 GB     DDR4
# 603  APPLE              M1             M1            10th  16 GB     DDR4
# 604  APPLE              M1             M1            10th  16 GB     DDR4
# 606  APPLE              M1             M1            10th  16 GB     DDR4
# 612  APPLE              M1             M1            10th  16 GB     DDR4
# 613  APPLE              M1             M1            10th  16 GB     DDR4
# 614  APPLE              M1             M1            10th  16 GB     DDR4
# 615  APPLE              M1             M1            10th   4 GB     DDR4
# 618  APPLE              M1             M1            10th  16 GB     DDR4
# 619  APPLE              M1             M1            10th  16 GB     DDR4
# ...

# %%
#multiple condition
df[(df['Price']>=80000)&(df['brand']=='APPLE')]
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 309  APPLE           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  APPLE           Intel        Core i5             8th   8 GB     DDR3
# 407  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 408  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 601  APPLE              M1             M1            10th  16 GB     DDR4
# 602  APPLE              M1             M1            10th   8 GB     DDR4
# 603  APPLE              M1             M1            10th  16 GB     DDR4
# 604  APPLE              M1             M1            10th  16 GB     DDR4
# 605  APPLE              M1             M1            10th   8 GB     DDR4
# 606  APPLE              M1             M1            10th  16 GB     DDR4
# ...

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df[(df['brand']=='HP')&(df['processor_brand']=='intel')&(df['ram_gb']=='8 GB')&(df['os_bit']=='64-bit')&(df['Price']==50000)]
# Out:
# Empty DataFrame
# Columns: [brand, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, warranty, Touchscreen, msoffice, Price, rating, Number of Ratings, Number of Reviews]
# Index: []

# %%
a=df[df['brand']=='DELL']
a.value_counts()
# Out:
# brand  processor_brand  processor_name  processor_gnrtn  ram_gb  ram_type  ssd     hdd      os       os_bit  graphic_card_gb  weight      warranty  Touchscreen  msoffice  Price   rating   Number of Ratings  Number of Reviews
# DELL   Intel            Core i3         11th             4 GB    DDR4      256 GB  1024 GB  Windows  64-bit  0 GB             ThinNlight  1 year    No           Yes       43590   3 stars  0                  0                    2
#                         Core i7         11th             16 GB   DDR4      512 GB  0 GB     Windows  64-bit  4 GB             Casual      1 year    No           No        99990   3 stars  0                  0                    2
#        AMD              Ryzen 3         Not Available    4 GB    DDR4      0 GB    1024 GB  Windows  64-bit  0 GB             ThinNlight  1 year    No           Yes       52632   3 stars  0                  0                    1
# ...

# %%
est=df[df['brand']=='HP']
est.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     136.000000         136.000000         136.000000
# mean    73640.272059         447.198529          50.485294
# std     36625.297509        1073.305823         121.424995
# min     26470.000000           0.000000           0.000000
# 25%     47690.000000           1.500000           0.000000
# 50%     59999.000000          39.500000           5.000000
# 75%     92247.500000         314.250000          42.750000
# max    239759.000000        7291.000000         895.000000
